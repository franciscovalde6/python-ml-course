# %% [markdown]
# ## Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 10000000
data = np.random.uniform(a, b, n)
data
# Out:
# array([ 1.19999946, 71.99388903, 94.69703369, ..., 88.75610995,
#        72.12460069, 25.50513538])

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([ 999559.,  999325.,  999842.,  999884.,  999449.,  998851.,
#         1000528., 1000646., 1000790., 1001126.]),
#  array([ 1.00000459, 10.90000401, 20.80000343, 30.70000285, 40.60000228,
#         50.5000017 , 60.40000112, 70.30000054, 80.19999996, 90.09999938,
#         99.99999881]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribución normal

# %%
data = np.random.randn(1000000)

# %%
data
# Out:
# array([ 1.52588089,  0.21143616,  1.19878503, ..., -2.42599213,
#         0.71759209,  0.72496256])

# %%
x = range(1,1000001)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([6.00000e+00, 2.61000e+02, 7.07600e+03, 6.98940e+04, 2.66133e+05,
#         3.86681e+05, 2.18558e+05, 4.73320e+04, 3.94700e+03, 1.12000e+02]),
#  array([-5.48720379, -4.47052011, -3.45383642, -2.43715274, -1.42046905,
#         -0.40378537,  0.61289831,  1.629582  ,  2.64626568,  3.66294937,
#          4.67963305]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x, sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(10000000)
plt.hist(data)
# Out:
# (array([5.800000e+01, 4.986000e+03, 1.313990e+05, 1.169808e+06,
#         3.540164e+06, 3.676710e+06, 1.311534e+06, 1.588580e+05,
#         6.398000e+03, 8.500000e+01]),
#  array([-8.15615388, -5.44439351, -2.73263314, -0.02087277,  2.6908876 ,
#          5.40264797,  8.11440834, 10.82616871, 13.53792908, 16.24968945,
#         18.96144982]),
#  <a list of 10 Patch objects>)
